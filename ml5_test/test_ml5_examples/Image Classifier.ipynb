# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from ml5_test import ml5_image

# %%
img_path = 'bird.jpg'
img = cv2.imread(img_path)
img_rgba = cv2.cvtColor(img, cv2.COLOR_BGR2RGBA)
width = 500
height = 500
resize_size = (width, height)
img_rgba = cv2.resize(img_rgba, resize_size)
x, y, channel = img_rgba.shape

# %%
plt.imshow(img_rgba)

# %% [markdown]
# ## using local file path

# %%
model1 = ml5_image.imageClassifier('MobileNet')
# Out:
# VBox(children=(imageClassifier(status='deferring flush until render'), Text(value='deferring flush until rende…
# ..........Modeal is ready

# %%
model1.classify_data(img_path,width=width,height=height)
# Out:
# ..done

# %%
model1.classify_callback_list
# Out:
# [[{'label': 'robin, American robin, Turdus migratorius',
#    'confidence': 0.9346750378608704},
#   {'label': 'worm fence, snake fence, snake-rail fence, Virginia fence',
#    'confidence': 0.0036658835597336292},
#   {'label': 'brambling, Fringilla montifringilla',
#    'confidence': 0.0026219470892101526}]]

# %% [markdown]
# ## using python image array

# %%
model2 = ml5_image.imageClassifier('MobileNet')
# Out:
# VBox(children=(imageClassifier(status='deferring flush until render'), Text(value='deferring flush until rende…
# ........Modeal is ready

# %%
data = img_rgba.flatten().tolist()

# %%
model2.classify_data(data,width=width,height=height)
# Out:
# .......done

# %%
model2.classify_callback_list
# Out:
# [[{'label': 'robin, American robin, Turdus migratorius',
#    'confidence': 0.9312140345573425},
#   {'label': 'worm fence, snake fence, snake-rail fence, Virginia fence',
#    'confidence': 0.0036170959938317537},
#   {'label': 'brambling, Fringilla montifringilla',
#    'confidence': 0.0029059872031211853}]]
